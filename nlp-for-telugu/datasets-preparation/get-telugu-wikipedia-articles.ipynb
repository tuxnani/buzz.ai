# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pickle
PATH = './datasets/TeluguWikipediaArticles/'
mapping_dict = {}

# %%
with open('all_telugu_wikipedia_links.pkl', 'rb') as f:
    all_urls = pickle.load(f)

# %%
len(all_urls)
# Out:
#   File "<ipython-input-6-47fd784b6d63>", line 2
#     print(type(all_urls[]))
#                         ^
# SyntaxError: invalid syntax

# %%
for counter, url in enumerate(all_urls):
#     counter = counter + 48247
    html_doc = ''
    try:
        with urlopen(url) as response:
            for line in response:
                line = line.decode('utf-8')
                html_doc = html_doc + line.replace('\n','')
        soup = BeautifulSoup(html_doc, 'html.parser')
        print(soup.title.string)
        paras = soup.find_all('p')
        article = ''
        for para in paras:
            article = article + para.text + '\n'
        article = re.sub(r'\([^)]*\)', r'', article)
        article = re.sub(r'\[[^\]]*\]', r'', article)
        article = re.sub(r'<[^>]*>', r'', article)
        article = re.sub(r'^https?:\/\/.*[\r\n]*', '', article)
        article = article.replace(u'\ufeff','')
        article = article.replace(u'\xa0', u' ')
        article = article.replace('  ', ' ');
        article = article.replace(' , ', ', ');
#         devanagari_nums = ('०','१','२','३','४','५','६','७','८','९')
#         for c, n in enumerate(devanagari_nums):
#             article = re.sub(n, str(c), article)
        filename = PATH + str(counter) + '.pkl'
        mapping_dict[filename] = soup.title.string
        with open(filename, 'wb') as f:
            pickle.dump(article,f)
        print("Saved " + filename)
    except:
        print('Failed')
        continue
#     break
# Out:
# పైన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/0.pkl
# కూరాడ (గుడ్లవల్లేరు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/1.pkl
# కొరుటూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/2.pkl
# తోటకూర - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3.pkl
# గదల - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/4.pkl
# నికాన్ డి3100 - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/5.pkl
# మన్నారుపోలూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/6.pkl
# మురళిగూడ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/7.pkl
# రావి వెంకటేశ్వరరావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/8.pkl
# వయసు కోరిక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/9.pkl
# రణం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/10.pkl
# చివుకుల ఉపేంద్ర - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/11.pkl
# ఉత్తటూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/12.pkl
# తన్నీరు హరీశ్ రావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/13.pkl
# దర్భగూడెం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/14.pkl
# అర్జల్‌ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/15.pkl
# రావినూతల (బోనకల్లు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/16.pkl
# సంరై - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/17.pkl
# జీళ్ళపాటూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/18.pkl
# గుర్రపువలస - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/19.pkl
# అమరావతి కథలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/20.pkl
# దుబ్బాపేట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/21.pkl
# రీతూ బర్మేచ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/22.pkl
# కొరిమెర్ల ఖండ్రిక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/23.pkl
# వెంకేపల్లి (మర్రిగూడ) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/24.pkl
# నరసాపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/25.pkl
# పెద ఆవుటపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/26.pkl
# పెదగడవిల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/27.pkl
# కేస్లాపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/28.pkl
# కొండపల్లి (రాజవొమ్మంగి మండలం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/29.pkl
# గడిమున్కాన్‌పల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/30.pkl
# కుర్రాడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/31.pkl
# కౌలేపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/32.pkl
# పెద్దూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/33.pkl
# మీనవల్లూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/34.pkl
# ధొండొ కేశవ కర్వే - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/35.pkl
# గద్దె రామ్మోహన్ రావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/36.pkl
# తువ్వపల్లె(పెండ్లిమర్రి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/37.pkl
# అంత్రాసైట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/38.pkl
# పాలక్కాడ్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/39.pkl
# భోగాపురం మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/40.pkl
# మొసం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/41.pkl
# బద్దెపురుగు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/42.pkl
# రేఖలకుంట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/43.pkl
# నంది ఉత్తమ డబ్బింగు కళాకారిణులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/44.pkl
# బీదరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/45.pkl
# రక్తాక్షి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/46.pkl
# నల్గొండ పట్టణం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/47.pkl
# పరివర్తన (1954 సినిమా) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/48.pkl
# మన్నవ బాలయ్య - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/49.pkl
# నవంబర్ 27 - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/50.pkl
# దేశాల జాబితా – సాయుధ దళాల పరిమాణం ప్రకారం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/51.pkl
# బన్నీ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/52.pkl
# శింగనమల మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/53.pkl
# ఎస్.మహతాబ్ బాంజీ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/54.pkl
# దౌలాపూర్ (జగ్దేవ్‌పూర్) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/55.pkl
# హరిత విప్లవం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/56.pkl
# కదసిల్ప - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/57.pkl
# ఆదర్శం (1952 సినిమా) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/58.pkl
# అందడు ఆగడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/59.pkl
# రాజుపేట అగ్రహారం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/60.pkl
# అలపర్తి వెంకటసుబ్బారావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/61.pkl
# కింజరాపు రామ్మోహన నాయుడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/62.pkl
# చేరుపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/63.pkl
# మార్కొండపుట్టి (అయోమయ నివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/64.pkl
# పెద్ద గౌరారం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/65.pkl
# పుల్లంగి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/66.pkl
# ఉత్తరాఖండ్ ముఖ్యమంత్రులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/67.pkl
# ఆచార్య ఎన్‌.జి.రంగా వ్యవసాయ విశ్వవిద్యాలయం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/68.pkl
# మనపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/69.pkl
# పోపూరి లలిత కుమారి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/70.pkl
# దొంగల బండి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/71.pkl
# అడ్లూరి అయోధ్యరామకవి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/72.pkl
# చింతగుంట (చంద్రగిరి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/73.pkl
# ఆదిమ వాసుల గిరిజన కళా రూపాలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/74.pkl
# వాడుకరి:Sivunnaidu yegireddi/ప్రభుత్వ పాఠశాలలే మేలు! - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/75.pkl
# యనమండ్ర నాగయజ్ఞ శర్మ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/76.pkl
# గాంధీనగరం (నూజెండ్ల) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/77.pkl
# అష్టాదశసిద్ధులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/78.pkl
# లద్దగిరి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/79.pkl
# జమ్మిచేడ్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/80.pkl
# ఖలిస్తాన్ కమెండో ఫోర్స్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/81.pkl
# బొమ్మారెడ్డి వెంకటేశ్వర రావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/82.pkl
# మడకశిర మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/83.pkl
# ఆడపిల్లలే నయం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/84.pkl
# కొండంపల్లె (బి.కోడూరు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/85.pkl
# వేల్పుచెర్ల శాసనం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/86.pkl
# కొర్లాం (గంట్యాడ) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/87.pkl
# ఇలపకుర్రు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/88.pkl
# అడవిరంగాపూర్ (వెంకటాపూర్‌) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/89.pkl
# కార్తె - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/90.pkl
# అట్టాడ అప్పల్నాయుడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/91.pkl
# డ్రాగన్ హార్ట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/92.pkl
# మంగ్లూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/93.pkl
# అత్తరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/94.pkl
# అమరుల రోజు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/95.pkl
# శ్రీరంగరాజపురం (పలమనేరు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/96.pkl
# ముచ్చుకోట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/97.pkl
# అల్‌ఖైదా - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/98.pkl
# బిద్ అత్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/99.pkl
# ముదక్‌పల్లి (నర్సింగ్‌పల్లి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/100.pkl
# కన్నేపల్లి చలమయ్య - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/101.pkl
# అథర్వణ వేదం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/102.pkl
# మురికివాడ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/103.pkl
# ఖాజీపూర్ (అయోమయ నివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/104.pkl
# భైనిగిల్లాన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/105.pkl
# కె.రామచంద్రాపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/106.pkl
# కోటపల్లె (గుడిపల్లె) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/107.pkl
# రామలింగస్వామి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/108.pkl
# శ్యాంప్రసాద్ ముఖర్జీ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/109.pkl
# వంగంపల్లె - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/110.pkl
# గొడిశాల - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/111.pkl
# ముద్దనపల్లె (రామకుప్పం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/112.pkl
# కంచిరావుపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/113.pkl
# రామన్నగూడెం (బుట్టాయగూడెం మండలం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/114.pkl
# విక్రమశిల విశ్వవిద్యాలయం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/115.pkl
# జొన్నలగడ్డ సత్యనారాయణమూర్తి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/116.pkl
# సువర్ణమాల - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/117.pkl
# పానింగపల్లి (పామర్రు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/118.pkl
# అహ్మద్ నగర్ కోట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/119.pkl
# కండలేరు ఆనకట్ట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/120.pkl
# నోయిడా - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/121.pkl
# తంబిగానిపల్లె - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/122.pkl
# గడికోట శ్రీకాంత్ రెడ్డి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/123.pkl
# ప్రెషరు గేజి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/124.pkl
# బ్రాహ్మణపల్లి (తాడిపత్రి మండలం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/125.pkl
# అంతరిక్షం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/126.pkl
# జింజిబర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/127.pkl
# అక్క - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/128.pkl
# విచిత్ర సోదరులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/129.pkl
# వేమకుంట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/130.pkl
# బోడోప్రజలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/131.pkl
# ఆచార్లపార్లపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/132.pkl
# బండారుగుంట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/133.pkl
# గోళ్ళమూడిపాడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/134.pkl
# అంబతాపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/135.pkl
# జో అచ్యుతానంద - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/136.pkl
# గాలిమేడలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/137.pkl
# తిరువూరు శాసనసభ నియోజకవర్గం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/138.pkl
# నరసక్కపేట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/139.pkl
# ప్రజ్ఞం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/140.pkl
# పెద్దాపూర్ (ఉప్పునూతల) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/141.pkl
# లినక్స్ మింట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/142.pkl
# పొనకలదిన్నె - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/143.pkl
# ఉపాధ్యాయ అర్హత పరీక్ష - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/144.pkl
# భగవాన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/145.pkl
# హైయన్ తుఫాన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/146.pkl
# మరాఠీ భాష - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/147.pkl
# పూడూరు (కర్నూలు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/148.pkl
# బసిరెడ్డిపాలెం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/149.pkl
# రంజాన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/150.pkl
# ధర్మపురి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/151.pkl
# సురేష్ (నటుడు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/152.pkl
# గండబోయనపల్లె - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/153.pkl
# వడ్లమాను - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/154.pkl
# బ్రాహ్మణ్‌పల్లి (నర్సాపూర్) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/155.pkl
# ఖశులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/156.pkl
# భూపతిపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/157.pkl
# యెర్రావారిపాలెం మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/158.pkl
# గిల్ల్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/159.pkl
# బొండపుట్టు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/160.pkl
# స్తఫొర్ద్‌పేట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/161.pkl
# హొరనాడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/162.pkl
# ఆవకాయ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/163.pkl
# రాజనందగావ్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/164.pkl
# పొట్లపల్లి (పినపాక) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/165.pkl
# తాండ్ర - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/166.pkl
# నేరేడుచర్ల - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/167.pkl
# రామభద్రాపురం (గంట్యాడ) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/168.pkl
# వజ్రోత్సవం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/169.pkl
# అరిమానిపాడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/170.pkl
# టెర్రర్ (2016 సినిమా) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/171.pkl
# లతాలక్ష్మి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/172.pkl
# భాస్కర్ నగర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/173.pkl
# రాజారావు (ఆంగ్ల రచయిత) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/174.pkl
# చర్మవ్యాధులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/175.pkl
# నూకలవారిపాలెం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/176.pkl
# కుకుర్బిటేసి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/177.pkl
# ఆత్మకథలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/178.pkl
# తెలుగు సినిమాలు 2008 - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/179.pkl
# జాల్నా - దాదర్‌ ముంబై జన శతాబ్ది ఎక్స్ ప్రెస్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/180.pkl
# అనంతరాగాలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/181.pkl
# తదేక గీతం-చైతన్య దీపం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/182.pkl
# ప్రయాణీకుడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/183.pkl
# బోరెగావ్ - 1 (కాగజ్‌నగర్‌) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/184.pkl
# రే చేప - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/185.pkl
# లక్ష్మీపురం (గొల్లప్రోలు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/186.pkl
# ఎస్.ఎస్. తమన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/187.pkl
# గోగర్భం ఆనకట్ట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/188.pkl
# జేమ్స్ గోస్లింగ్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/189.pkl
# శాంతి పర్వము ప్రథమాశ్వాసము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/190.pkl
# బొరగం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/191.pkl
# హౌరా-చెన్నై ప్రధాన రైలు మార్గము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/192.pkl
# గొల్లపాడు (అయోమయనివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/193.pkl
# లింగారెడ్డిపల్లి (దామరగిద్ద) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/194.pkl
# పల్లవోలు (కలికిరి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/195.pkl
# సింగమ్నేనిపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/196.pkl
# మే 25 - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/197.pkl
# ఇంగ్లీషు-తెలుగు నిఘంటువు (L) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/198.pkl
# లిథియం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/199.pkl
# వాల్మీకి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/200.pkl
# సంస్కృత న్యాయములు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/201.pkl
# తురక చాకలి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/202.pkl
# పైన్ గింజల నూనె - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/203.pkl
# బారు అలివేలమ్మ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/204.pkl
# అరటి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/205.pkl
# గెమ్మెలిబరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/206.pkl
# అతడు (సినిమా) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/207.pkl
# ఏకవింశతి పత్రపూజ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/208.pkl
# ఇరికేపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/209.pkl
# ఎ ఫిల్మ్ బై అరవింద్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/210.pkl
# రామచంద్రపాలెం (గారపాడు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/211.pkl
# ర్యాలి (మంచిర్యాల) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/212.pkl
# వేచరేణి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/213.pkl
# కుర్మల్‌గూడ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/214.pkl
# గానకళ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/215.pkl
# పనస (గ్రామం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/216.pkl
# మాగుంట సుబ్బరామిరెడ్డి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/217.pkl
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# Failed
# సలిమెరంగి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3249.pkl
# హీరో - 76 - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3250.pkl
# ఫిడెల్ కాస్ట్రో - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3251.pkl
# గుమ్మదవెల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3252.pkl
# కిదాంబి శ్రీకాంత్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3253.pkl
# గొల్లప్రోలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3254.pkl
# దెందులూరు మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3255.pkl
# మదన గోపాలుడు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3256.pkl
# పైడిపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3257.pkl
# మొగుళ్లవంపు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3258.pkl
# ఇ.వి.సరోజ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3259.pkl
# Failed
# Failed
# అబలా బోస్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3262.pkl
# భీమన్నదొరపాలెం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3263.pkl
# నువ్వులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3264.pkl
# ఉప్పలూరు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3265.pkl
# గాతలవలస - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3266.pkl
# డి లా ర్యూ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3267.pkl
# వాఘాపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3268.pkl
# మహాత్మా గాంధీ హత్య - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3269.pkl
# ప్రతాప్ సి. రెడ్డి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3270.pkl
# మక్తల్ అసెంబ్లీ నియోజకవర్గం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3271.pkl
# ముహమ్మద్ రఫీ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3272.pkl
# శుక్రవారము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3273.pkl
# కుత్బుల్లాపూర్ (అబ్దుల్లాపూర్‌మెట్ మండలం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3274.pkl
# హరిపురం (మందస) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3275.pkl
# కల్లూరు, లేపాక్షి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3276.pkl
# నక్సలైటు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3277.pkl
# పుష్య శుద్ధ విదియ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3278.pkl
# ఖలీఫా - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3279.pkl
# ఘన్‌పూర్ (నెన్నెల్ మండలం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3280.pkl
# ఘన్‌పల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3281.pkl
# అశ్వత్థామ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3282.pkl
# తర్నాం (ఖుర్ద్) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3283.pkl
# ప్రేమ్‌కుమార్ ధుమాల్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3284.pkl
# గూడూరు (చింతూరు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3285.pkl
# చలనాట రాగము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3286.pkl
# అనూప్ రూబెన్స్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3287.pkl
# పాలమంగళం దక్షిణి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3288.pkl
# లక్ష్మీబాయి షిండే - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3289.pkl
# మల్లిక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3290.pkl
# భాద్రపద బహుళ అష్ఠమి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3291.pkl
# చిన్నారి ముద్దులపాప - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3292.pkl
# మానవ పరిణామం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3293.pkl
# వోగు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3294.pkl
# బండిగెడ్డ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3295.pkl
# చింతగొండి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3296.pkl
# తిరుమలగిరి (బొమ్మలరామారం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3297.pkl
# బైరాపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3298.pkl
# తెలుగు సినిమాలు 1989 - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3299.pkl
# పిశుపాటి విశ్వేశ్వరశాస్త్రి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3300.pkl
# ఉట్లపల్లి (బాలాయపల్లి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3301.pkl
# వికీపీడియా:సాధారణ పదదోషాలు - తప్పొప్పుల పట్టిక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3302.pkl
# బండివారిగూడెం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3303.pkl
# శ్రీమతి కానుక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3304.pkl
# యాపిల్ ఇన్‌కార్పొరేషన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3305.pkl
# సత్య నాదెళ్ల - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3306.pkl
# పోపూరి లలిత కుమారి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3307.pkl
# మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3308.pkl
# సంతోషపురం (కలిదిండి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3309.pkl
# ద్వారక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3310.pkl
# ఇరుసుమండ (మలికిపురం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3311.pkl
# కొండాపూర్ (కొడిమ్యాల్) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3312.pkl
# కాపుసంభం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3313.pkl
# ఫిలిప్పైన్ ఎయిర్‌లైన్స్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3314.pkl
# లక్ష్మీకాంతం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3315.pkl
# తిరుమల ఊంజల్ సేవ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3316.pkl
# ప్రాథమిక మూలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3317.pkl
# సుందర చైతన్యానంద - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3318.pkl
# సిరిసిరిమువ్వ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3319.pkl
# కిలారి ఆనంద్ పాల్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3320.pkl
# సతివాడ (తెర్లాం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3321.pkl
# తాలిపేరు నది - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3322.pkl
# సమతామూర్తి శ్రీమద్రామానుజ స్పూర్తి కేంద్రం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3323.pkl
# పోలుమల్ల - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3324.pkl
# ఆలమండ (జియ్యమ్మవలస) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3325.pkl
# వెంకటగిరి (బంగారుపాలెం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3326.pkl
# దీపావళి (అయోమయ నివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3327.pkl
# నంది ఉత్తమ బాలనటీమణులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3328.pkl
# ఆళ్లపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3329.pkl
# గంగవరం (మాకవరపాలెం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3330.pkl
# జీవితాలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3331.pkl
# పెడాలియేసి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3332.pkl
# మల్లవరం (గోకవరం మండలం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3333.pkl
# మురపాక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3334.pkl
# విప్ (రాజకీయాలు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3335.pkl
# మల్యాల్ (జన్నారం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3336.pkl
# నడింపల్లి (అయోమయ నివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3337.pkl
# అడ్డసరం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3338.pkl
# పెదకాకాని హాల్ట్ రైల్వే స్టేషను - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3339.pkl
# ఎల్లాప్రగడ రామచంద్రరావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3340.pkl
# మూలకము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3341.pkl
# విరూపాక్షపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3342.pkl
# దీవి శ్రీనివాసాచార్యులు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3343.pkl
# తెర్నేకళ్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3344.pkl
# విభలపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3345.pkl
# వేలూరి శివరామ శాస్త్రి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3346.pkl
# సునీల్‌ మిత్తల్‌ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3347.pkl
# ఎ. ఆర్. రెహమాన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3348.pkl
# బేరియం సల్ఫేట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3349.pkl
# శ్యామ్ బెనగళ్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3350.pkl
# ప్రత్తిపాడు శాసనసభ నియోజకవర్గం (అయోమయ నివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3351.pkl
# కొట్లాపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3352.pkl
# సోవియట్ యూనియన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3353.pkl
# బైబిల్లో ప్రస్తావించిన ప్రముఖ వ్యక్తుల జాబితా - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3354.pkl
# బొంతగట్టునాగారం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3355.pkl
# నారాయణరెడ్డిపేట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3356.pkl
# తమ్మారెడ్డి భరద్వాజ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3357.pkl
# వేంగి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3358.pkl
# భారతీయ డీమ్డ్ విశ్వవిద్యాలయాల జాబితా - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3359.pkl
# సోడియం అసిటేట్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3360.pkl
# కొత్త సంవత్సరం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3361.pkl
# కృష్ణంపల్లె (ఏర్పేడు) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3362.pkl
# వైశాఖ శుద్ధ ద్వాదశి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3363.pkl
# సంస్థ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3364.pkl
# ఇంటర్నెట్ విజ్ఞాన సర్వస్వము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3365.pkl
# క్లాస్‌మేట్స్‌ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3366.pkl
# నాగాలాండ్ విశ్వవిద్యాలయం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3367.pkl
# గద్వాల పురపాలక సంఘము - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3368.pkl
# ఇస్మాయీల్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3369.pkl
# ఎన్నీల ముచ్చట్లు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3370.pkl
# నా ఇల్లే నా స్వర్గం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3371.pkl
# షాఅబ్దుల్లాపాలెం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3372.pkl
# ఏదులాపూర్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3373.pkl
# వ్యవసాయ పంచాంగం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3374.pkl
# నిర్మలా సీతారామన్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3375.pkl
# అత్తలూరి నరసింహారావు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3376.pkl
# మాకమాంబపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3377.pkl
# కొడంగల్ మండలం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3378.pkl
# గురవాజీపేట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3379.pkl
# పోడ్చెన్‌పల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3380.pkl
# మల్లేపల్లి - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3381.pkl
# సుప్రసిద్ధుల జీవిత విశేషాలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3382.pkl
# అష్టవిధ నాయికలు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3383.pkl
# కొట్లాపూర్ ఖుర్ద్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3384.pkl
# భట్లపల్లి (మర్రిగూడ) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3385.pkl
# చెక్ రిపబ్లిక్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3386.pkl
# బలోడా బజార్ - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3387.pkl
# భీమవరం (కేతేపల్లి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3388.pkl
# ఎం.వెంకటాపురం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3389.pkl
# స్వాతి మాసపత్రిక - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3390.pkl
# గ్రీన్‌హౌస్(హరితగృహం) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3391.pkl
# శివాపురం (కొత్తపల్లె) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3392.pkl
# మంగళం (తిరుపతి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3393.pkl
# పరిటాల (అయోమయ నివృత్తి) - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3394.pkl
# రణంకోట - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3395.pkl
# లలితా సహస్రనామ స్తోత్రం - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3396.pkl
# బంగారుపుట్టు - వికీపీడియా
# Saved ./datasets/TeluguWikipediaArticles/3397.pkl
# Failed
# Failed
# Failed
# Failed
